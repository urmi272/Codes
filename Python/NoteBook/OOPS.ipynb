# %% [markdown]
# OOPS:
#
# Classes and Objects
# Abstract
# Polymorphism
# Inheritance
# Encapsulation
# Iterators

# %% [markdown]
# Class is a user-defined data type. It consists of data members and member functions, which can be accessed and used by creating an instance of that class-->object. A class is like a blueprint for an object.
#
# Object are real=life enterties, memory is alloted when object is created. Objects can interact without having to know details of each other’s data or code.
#
#
#
#
# class ClassName:
#    def __ init__(self, arg1, arg2):
#         self.arg1 = arg1
#         self.arg2 = arg2
#     def some_method(self):
#         # Method definition
#         pass
#
# obj = ClassName(x , y)
# print(obj.some_method())

# %% [markdown]
# Data abstraction refers to providing only essential information about the data to the outside world, hiding the background details or implementation.

# %% [markdown]
# Encapsulation is defined as the wrapping up of data under a single unit. It is the mechanism that binds together code and the data it manipulates and can be accessed only through any member function of their class in which they are declared.

# %% [markdown]
# Inheritance is the capability of a class to derive properties and characteristics from another class. Inheritance allows the user to reuse the code whenever possible and reduce its redundancy.
# ![alt text](InheritanceinObjectOrientedProgramming.png)

# %% [markdown]
# polymorphism is the ability of a message to be displayed in more than one form.![alt text](PolymorphisminObjectOrientedProgramming.png)

# %% [markdown]
# Dynamic binding means that the code associated with a given procedure call is not known until the time of the call at run time

# %% [markdown]
# Message passing involves specifying the name of the object, the name of the function, and the information to be sent. A message for an object is a request for execution of a procedure and therefore will invoke a function in the receiving object that generates the desired results.

# %%
class person:
    name = "Jule"
    occ = "Lawyer"
    
    def info(self): #self is reference to the class and used to excess class variable
        print(f"{self.name} is a {self.occ}")

obj = person() #creating objects of class person
obj.info()
obj2 = person()
obj2.name = "Josh"
obj2.occ = "Docter"
obj2.info()
#print(obj.name, obj.occ)
# Out:
# Jule is a student
# Josh is a Docter

# %% [markdown]
# constructor gets automatically gets called whenever an object is created

# %%
class person:
    school = "Royal Elite" #class variable
    def __init__(self, name , occ): #paramitrize contructor 
        print("hii, i'm a constructor")
        self.n = name #instance variable
        self.o = occ
        self.age = 20 #initializing

    def info(self): #defining methods
        print(f"{self.n} is a {self.o} \nAge: {self.age}")
    def info2(self):
        print(f"School : {self.school}")

obj = person("Aiden","student")

obj.info()
obj.info2()
# Out:
# hii, i'm a constructor
# Aiden is a student
# Age: 20
# School : Royal Elite

# %%
class Bank:
    def __init__(self, AccNo, Name):
        self.a =AccNo
        self.n =Name
        self.Bal =  0

    def deposit(self, d):
        self.Bal += d 
        print("Amount deposite successfully!")
    
    def withdraw(self, w):
        if w>self.Bal:
            print("Insufficient balance")
        else:
            self.Bal -= w
            print("Amount withdraw succesfully")
    
    def Check(self):
        print(f"Your Current account balance is: {self.Bal}")

    def display(self):
        print(f"Account number: {self.a}")
        print(f"Account Holder name: {self.n}")

x = Bank(123, 'XYZ')
x.deposit(1000)
x.Check()
x.withdraw(3000)
x.withdraw(500)
x.Check()
x.display()
# Out:
# Amount deposite successfully!
# Your Current account balance is: 1000
# Insufficient balance
# Amount withdraw succesfully
# Your Current account balance is: 500
# Account number: 123
# Account Holder name: XYZ

# %%
class Base:
    def __init__(self,name, Id):
        self.n= name
        self.id = Id

    def show(self):
        print(f"Name of Id no.{self.id} is {self.n}")

class Derived(Base): #Inheritance
    def speak(self):
        print("Can speak 3 language")

obj = Base("Anjali", 2023)
obj.show()
#obj.speak() #this is not possible
oj = Derived('Urmi', 2022)
oj.show()
oj.speak()
# Out:
# Name of Id no.2023 is Anjali
# Name of Id no.2022 is Urmi
# Can speak 3 language

# %%
class Singer:
    def __init__(self, name):
        self.n = name
    def show(self):
        print("Singer name")

class Stream:
    def __init__(self, country):
        self.c = country
    def show(self):
        print("Country they belong")

class Spotify(Singer, Stream): #Multiple inheritance
    def __init__(self, name, country):
        self.n = name
        self.c = country

x = Spotify("US", "Taylor Swift")
print(x.n)
print(x.c)
x.show() #whatever is written 1st will be the priority
print(Spotify.mro()) #it will show the prirority list
# Out:
# US
# Taylor Swift
# Singer name
# [<class '__main__.Spotify'>, <class '__main__.Singer'>, <class '__main__.Stream'>, <class 'object'>]

# %%
class Animal:
    def __init__(self, name, species):
        self.n = name
        self.s = species
    def show(self):
        print(f"Name: {self.n} \nSpecies: {self.s}")

class Dog(Animal): #multilevel inheritance
    def __init__(self, name, breed):
        Animal.__init__(self, name, species = "Dog")
        self.b = breed
    def show(self):
        Animal.show(self)
        print(f"Breed: {self.b}")

class GoldenRetriver(Dog): #multilevel inheritance
    def __init__(self, name, color):
        Dog.__init__(self, name, breed = "Golden Retriver")
        self.c = color
    def show(self):
        Dog.show(self)
        print(f"Color: {self.c}")

obj = GoldenRetriver("Jacky", "Black")
obj.show()
# Out:
# Name: Jacky
# Species: Dog
# Breed: Golden Retriver
# Color: Black

# %%
class person:
    def __init__(self,name, age, gender):
        self.n = name
        self.a = age
        self.ad = "Bhopal"
        self.g = gender

class Std(person): #Hierarchical inheritance
    def __init__(self,name, age, gender, branch):
        super().__init__(name, age, gender) #Super keyword use to override parent methods
        self.b = branch
        print("---Student details---")
    def display(self):
        print(f"Name: {self.n}")
        print(f"Age: {self.a}")
        print(f"Address: {self.ad}")
        print(f"Gender: {self.g}")
        print(f"Branch: {self.b}")

class Faculty(person): #Hierarchical inheritance
    def __init__(self,name, age, gender, school):
        super().__init__(name, age, gender)
        self.s = school
        print("---Faculty details---")
    def display(self):
        print(f"Name: {self.n}")
        print(f"Age: {self.a}")
        print(f"Address: {self.ad}")
        print(f"Gender: {self.g}")
        print(f"School: {self.s}")

s1 = Std("Urmi", 20,"Female","Btech" )
s1.display()
f1 = Faculty("Poonkurtan", 50, "Male","SCSE")
f1.display()
# Out:
# ---Student details---
# Name: Urmi
# Age: 20
# Address: Bhopal
# Gender: Female
# Branch: Btech
# ---Faculty details---
# Name: Poonkurtan
# Age: 50
# Address: Bhopal
# Gender: Male
# School: SCSE

# %% [markdown]
# By default python has public variable

# %%
class Employee:
    def __init__(self):
        self.__name = 'Urmi' #private variable
obj = Employee()
# print(obj.__name) #can't access directly
print(obj._Employee__name) #can access directly
# Out:
# Urmi

# %%
class Employee:
    def __init__(self):
        self._name = 'Urmi' #protected variable
obj = Employee()
print(obj._name)
# Out:
# Urmi

# %% [markdown]
# An abstract class can be considered a blueprint for other classes. It allows you to create a set of methods that must be created within any child classes built from the abstract class.
#
# A class that contains one or more abstract methods is called an abstract class. An abstract method is a method that has a declaration but does not have an implementation.

# %%
#abstrctmthd means every sub class must redefine that method
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def Area(self):
        return 0 #pass
    
class Rec(Shape):
    def __init__(self,l,b):
        self.l = l
        self.b = b
    def Area(self):
        return self.l*self.b
class circle(Shape):
    def __init__(self,r):
        self.r = r
    def Area(self):
        return 3.14*(self.r)**2
    
r = Rec(3,4)
c = circle(4)
print(r.Area())
print(c.Area())
# Out:
# 12
# 50.24

# %%
class Employee:
    company = "Apple"
    def show(self):
        print(f"The name is {self.name} and company is {self.company}")

    @classmethod #to change class variable 
    def change(cls, newcom):
        cls.company = newcom
e1 = Employee()
e1.name = "Urmi"
e1.show()
e1.change("Tesla")
e1.show()
print(Employee.company)
# Out:
# The name is Urmi and company is Apple
# The name is Urmi and company is Tesla
# Tesla

# %%
class Employee:
    def __init__(self, name, salary) -> None:
        self.n = name
        self.s = salary
    @classmethod #they can be used as alternative constructors
    def ifStr(cls, str):
        return cls(str.split("-")[0] #represanting name
                   , int(str.split("-")[1])) #represanting Salary

e1 = Employee("Urmi", 100)
print(e1.n)
print(e1.s)

string = "Aaron-200"
e2 = Employee.ifStr(string)
print(e2.n)
print(e2.s)
# Out:
# Urmi
# 100
# Aaron
# 200

# %% [markdown]
# Method overloading: Super keyword use to override parent methods

# %%
class parent:
    def hello(self):
        print("this is parent method")

class child(parent):
    def hello(self):
        print("override using Super keyword")
        super().hello()
    def hii(self):
        print("this is child method")

c = child()
c.hii()
c.hello()
# Out:
# this is child method
# override using Super keyword
# this is parent method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# operator overloading

# %%
class Vector:
    def __init__(self, i, j , k):
        self.i = i
        self.j = j
        self.k = k
    def __str__(self): #overring str
        return f"{self.i}i + {self.j}j + {self.k}k"
    
    def __add__(self, x): #override add(+)
        return Vector(self.i + x.i, self.j + x.j, self.k + x.k)
    
v1 = Vector(1,2,3)
print(v1)
v2 = Vector(4,5,6)
print(v2)

print(v1 + v2) # add--> + and we r passing v2 as argument
print(type(v1 + v2))
# Out:
# 1i + 2j + 3k
# 4i + 5j + 6k
# 5i + 7j + 9k
# <class '__main__.Vector'>

# %% [markdown]
# ![](attachment:image.png)
