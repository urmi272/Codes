# %%
x = 34 - 23
y = "Hello"
z = 3.45
if z == 3.45 or y == "Hello":
  x = x + 1
  y = y + "World"
  z = z//2
  print (x)
  print (y)
  print (z)
# Out:
# 12
# HelloWorld
# 1.0

# %%
p = "abc"
type (p)
# Out:
# str

# %%
q = 1000
type (q)
# Out:
# int

# %%
x = 1/2 + 4*3 - 6
print (x)
# Out:
# 6.5

# %% [markdown]
# tuple vs list

# %%
my_list = [1, 2, 3, 4]
my_tuple = (4, 5, 6, 7)

print(my_list[0])
print(my_tuple[2])
# Out:
# 1
# 6

# %%
my_list[3] = 77
print (my_list)
# Out:
# [1, 2, 3, 77]

# %%
my_tuple[3] = 77
print (my_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e6bbd6c8f7c2> in <cell line: 1>()
# ----> 1 my_tuple[3] = 77
#       2 print (my_tuple)
#
# TypeError: 'tuple' object does not support item assignment
