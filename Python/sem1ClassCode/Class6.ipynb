# %%
list = [1,2,3,4,6]
list.insert(2,25)
print(list)

list.append(30)
print(list)
# Out:
# [1, 2, 25, 3, 4, 6]
# [1, 2, 25, 3, 4, 6, 30]

# %%
from array import array
arr = array('i', [1,2,3,4,5,6])
arr.insert(2,25)
print(arr)

arr.append(30)
print(arr)

print(arr.index(2))
# Out:
# array('i', [1, 2, 25, 3, 4, 5, 6])
# array('i', [1, 2, 25, 3, 4, 5, 6, 30])
# 1

# %%
import numpy as np
